# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Default and Rest Parameters
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Esto provoca que no podemos esperar polimorfismo en JS, es decir, definir 2 funciones con el mismo nombre y diferente no. de parametros y esperar que JS reconozca la diferencia.. Simplemente este feature no esta disponible en JS. Si se definen 2 funciones con el mismo nombre, la 2da sustituye a la primera

# %% [markdown]
# ## Rest parameter: debe ser el ultimo en la lista. Es un arreglo de parametros sobre el cual se puede iterar
# ![image.png](attachment:image.png)

# %% [markdown]
# # Functions that return results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Functions as Arguments to Other Functions

# %% [markdown]
# ## JavaScript functions can be treated as objects, which means you can use one function as the argument to another
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Arrow Functions
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Variables and Types
# ## - let declares variable which value can be changed
# ## - const declare constants
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ### Resultado dependiendo de como se declare la variable
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # USING VARIABLE CLOSURE
#
# ### If you define a function inside another function—creating inner and outer functions—then the inner
# ### function is able to access the outer function’s variables, using a feature called closure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using the Primitive Types
# ### Los tipos primitivos principales son <code>string, number y boolean</code>.
# ### <code>undefined</code> significa variable declarada pero que no ha sido asignado valor. <code>null</code> es que no tiene valor
# ### Number type representa integers y floating points

# %% [markdown]
# # Using Template Strings
# ![image.png](attachment:image.png)

# %% [markdown]
# # Operadores
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Nota importante sobre los operadores equality (==) e identity (===)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### El operador <code>+</code> cuando se usa para concatenar tiene precedencia sobre la suma
# ![image.png](attachment:image.png)

# %% [markdown]
# # Working with Arrays
#
# ## Declaracion usando el objeto Array()
# ![image.png](attachment:image.png)
#
# ## Declaracion usando el literal
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Enumerando elementos
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Using the Spread Operator
# ### Este operador "desempaca" los elementos del array para que puedan usarse como parametros de una funcion
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hay un monton de metodos para manejar arreglos
#
# <ul>
#   <li><strong>concat(otherArray)</strong> – Returns a new array that concatenates the array on which it has been called with the array specified as the argument. Multiple arrays can be specified.</li>
#   <li><strong>join(separator)</strong> – Joins all the elements in the array to form a string. The argument specifies the character used to delimit the items.</li>
#   <li><strong>pop()</strong> – Removes and returns the last item in the array.</li>
#   <li><strong>shift()</strong> – Removes and returns the first element in the array.</li>
#   <li><strong>push(item)</strong> – Appends the specified item to the end of the array.</li>
#   <li><strong>unshift(item)</strong> – Inserts a new item at the start of the array.</li>
#   <li><strong>reverse()</strong> – Returns a new array that contains the items in reverse order.</li>
#   <li><strong>slice(start, end)</strong> – Returns a section of the array.</li>
#   <li><strong>sort()</strong> – Sorts the array. An optional comparison function can be used to perform custom comparisons.</li>
#   <li><strong>splice(index, count)</strong> – Removes <em>count</em> items from the array, starting at the specified index. The removed items are returned.</li>
#   <li><strong>unshift(item)</strong> – Inserts a new item at the start of the array.</li>
#   <li><strong>every(test)</strong> – Calls the test function for each item in the array and returns true if the function returns true for all items.</li>
#   <li><strong>some(test)</strong> – Returns true if calling the test function for each item returns true at least once.</li>
#   <li><strong>filter(test)</strong> – Returns a new array containing the items for which the test function returns true.</li>
#   <li><strong>find(test)</strong> – Returns the first item in the array for which the test function returns true.</li>
#   <li><strong>findIndex(test)</strong> – Returns the index of the first item in the array for which the test function returns true.</li>
#   <li><strong>forEach(callback)</strong> – Invokes the callback function for each item in the array.</li>
#   <li><strong>includes(value)</strong> – Returns true if the array contains the specified value.</li>
#   <li><strong>map(callback)</strong> – Returns a new array containing the result of invoking the callback function for every item.</li>
#   <li><strong>reduce(callback)</strong> – Returns the accumulated value produced by invoking the callback function for every item in the array.</li>
# </ul>

# %% [markdown]
# '![image.png](attachment:image.png)

# %% [markdown]
# # Working with Objects
# ### Varias formas de crear objetos en JS
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Functions as Methods
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Copying Properties from One Object to Another
# ![image.png](attachment:image.png)

# %% [markdown]
# # Understanding JavaScript Modules
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Si se omite el punto o la @, el dependency se busca en el folder node_modules
# ![image.png](attachment:image.png)

# %% [markdown]
# # Defining Multiple Features in a Module
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# '![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Combining Multiple Files in a Module
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Importing Individual Features from a Multifile Module
# ![image.png](attachment:image.png)

# %% [markdown]
# # Understanding JavaScript Promises
